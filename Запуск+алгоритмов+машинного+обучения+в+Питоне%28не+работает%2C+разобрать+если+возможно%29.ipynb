# %%
import pandas
 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn import ensemble
from sklearn import svm
 
data = pandas.read_csv('titanic.csv', index_col='PassengerId')
 
print(data)
print(data['Sex'].value_counts())

print(data['Survived'].value_counts())

age = data['Age']
print("%.2f %.2f" % (age.mean(), age.median()))

name = data[data.Sex == "female"]['Name']
print(name)

 
 
 
#####################
 
Xy = data[['Pclass', "Fare", "Age", "Sex", "Survived"]].dropna()
Xy.replace("male", 0, True, None, False)
Xy.replace("female", 1, True, None, False)

print(Xy['Survived'].value_counts())
# 
# 
X = Xy[['Pclass', "Age", "Sex"]].values
y = Xy['Survived'].values

clf = DecisionTreeClassifier(random_state=241)
clf.fit(X, y)
 
importances = clf.feature_importances_
print(importances)
print(clf)
print(clf.get_params())

tree.export_graphviz(clf, out_file='tree.dot')   
 

######################
print(clf.predict([[3, 24, 1]]))
######################


clf = Perceptron(random_state=241)
clf = LogisticRegression(random_state=241)
clf = Ridge(random_state=241)
clf = svm.SVC(random_state=241)
clf = ensemble.RandomForestClassifier(random_state=241)
clf = ensemble.AdaBoostClassifier(random_state=241)
clf = MLPClassifier(random_state=241)
clf = BernoulliRBM(random_state=241)
clf.fit(X, y)

print(clf.predict([[1, 99, 0]]))
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
# 21                  0       2
# 22                  1       2
# 23                  1       3
# 24                  1       1
# 25                  0       3
# 26                  1       3
# 27                  0       3
# 28                  0       1
# 29                  1       3
# ...

# %% [raw]
# # http://deep.uran.ru/wiki/index.php?title=%D0%97%D0%B0%D0%BF%D1%83%D1%81%D0%BA_%D0%B0%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D0%BE%D0%B2_%D0%BC%D0%B0%D1%88%D0%B8%D0%BD%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BE%D0%B1%D1%83%D1%87%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2_%D0%9F%D0%B8%D1%82%D0%BE%D0%BD%D0%B5
